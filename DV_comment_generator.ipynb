# %% [markdown]
# <a href="https://colab.research.google.com/github/dhk92/dv-comment-generator/blob/main/DV_comment_generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Data import**

# %%
from google.colab import drive
from os.path import join
import os
import torch
import torch.nn as nn
import torch.nn.functional as functional
import numpy as np
import matplotlib.pyplot as plt
import json
import pandas as pd
from collections import Counter


ROOT="/content/drive"
drive.mount(ROOT)
PROJ="My Drive/Deep learning/DV_comment_generator"
PROJ_PATH=join(ROOT,PROJ)

# !rsync -aP "{PROJ_PATH}"/* ./

def read_comments(comments):
  files = [f for f in os.listdir('.') if f.endswith('.json')]
  for file in files:
    print(file)
    with open(file) as fil:
        data = json.load(fil)
        for article in data:
          for comment in article['comments']:
            if comment != '':
              comments.append(comment)
          

comments = []
read_comments(comments)
print(comments)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# sending incremental file list
# dvcom04.json
# dvcom01.json
# dvcom03.json
# dvcom02.json
# ['I see what you did there 😉', 'Flott hjá henni', 'Æi greyið, hún hlýtur að vera með sinaskeiðabólgu fyrst að hún getur bara 3 sinnum á dag.', 'Já ætli hún fái ekkert annað grei stulkan...en nb ... hverslags fréttir eru þetta ... jahérnahét', 'Þak á verðtrygginguna. Miðað við allt sem stjórnvöld geta gert í tengslum við kórónuveiruna ættu þeir að setja þak þannig að fólk þurfi ekki að standa í endurfjármögnun.', 'helt að þu værir látinn ekki orð eftir að Drifan neitaði Bjarna að afnema VERÐTRYGGINUNA', 'Finnst blaðamanninum þessi snúður vera bardagakappi? Er þetta leiðtogi lífs þíns herra blaðamaður? Því kallar þú hann ekki því nafni sem hann er, ofbeldismaður, kókfíkill eða fáviti?', 'Hann Gulli er á verulega slæmum stað í lífinu.', 'Gunnar Nelson er bardagakappinn en þessi Júlli er ofbeldismaður með nefið fullt af kóki! En svo eru það hinir sem eru en verri þar sem eiturlyfin gjörsamlega breyta allri hugsun í að vera siðlausir!', 'það er engin afsökun að vera a kóki eða neinu öðru og haga sér eins og faviti. ég er sjálf buin að nota helling af fíkniefnum i gegnum tíðina en hef aldrei breyst í fávita.', 'Bjarney Lára Sævarsdóttir fer eftir folki', 'Hvað tengist mma þessu máli ..', 'Hann æfir mma hjá Mjölni', 'Gunnar Anderson nei hann fær hvergi að æfa!', 'Þeir reiða nú ekki vitið í þverpokum þessar veslings mannleysur. En eru þetta ekki fjölbýlishús í báðum tilfellum og lífi fólks stefnt í stórkostlega hættu sem hlýtur að nægja til að koma þessum bjánum í gæsluvarðhald.', 'Fávitar þeir sem gera svona og þora ekki að standa fyrir framan viðkomandi eru bara aumingjar , i raun ætti að setja vakt á húsið ég meina það 3 árásir. Hvað næst íkveikja um nótt.', 'Hvað er málið hjá DV? Til hvers að birta þessa frétt í mörgum hlutum, alltaf nýtt á hverjum degi. Mér finnst grunsamlegt aðgengi DV að alskonar myndböndum af ýmsu sem ætti í raun bara að vera í höndum lögreglu. Nú er búið að persónugera þetta fífl sem veifar byssum og kveikir í húsum. Nú á þessi náungi bjarta framtíð í undirheimunum. Ég skil ekki svona fréttamennsku.', 'kanski þvi það kemur alltaf upp nýtt í þessu máli ...', 'Hann þótti liðtækur í skák..\nEkki er fjallað um skák kappann', 'A.m.k. pössuðu þau uppá að kasta kokteilnum inn í rétt hús?\nÞað er ekki gefið að svona pakk hafi vitsmunina til þess.', 'Alfreð er náturulega hreinn snillingur og eðalmenni.', 'Halda menn virkilega að þeir komist upp með ofbeldi og læti ef þeir blasta því svo á alheimsnetið ??', 'alveg ótrúleg heimska!', 'Gefur orðinu "kappi" nýja merkingu.', 'Finnst blaðamanninum þessi snúður vera bardagakappi? Er þetta leiðtogi lífs þíns herra blaðamaður? Því kallar þú hann ekki því nafni sem hann er, ofbeldismaður, kókfíkill eða fáviti?', 'Hann er kannski bardagakappi öllu jafna. Hann hefur væntanlega eyðilegt feril sinn með því að beita ofbeldi og vera svo firrtur að hann deilir því á netið. Þannig að þessi maður á varla afturkvæmt í íþróttina næstu árin eftir þessa hegðun.', 'Jonna Sverrisdóttir hann er FYRRUM BARDAGAKAPPI það er munur á að vera og var....', 'Hann er engin bardagakappi! Bardagakappar eru þeir sem stunda íþrótt sína með heillindum og sóma í hringnum eða æfingasölum, þeir nota ekki kunnáttu sína á MMA til að ógna öðrum. Kallið þennan gaur það sem hann er, a wannabe gangster sem einhvern tíman æfði MMA, því það mundi enginn almennilegur MMA æfinga klúbbur hleypa þessum manni inn á sitt svæði!!', "well wannabe gangster er ekki það sem hann er ..\nefast um að þú veist hvað ''gangster'' þyðir", 'Patrekur Bjarni Þorbjargarson Ég veit fyllilega hvað það þýðir!', 'Vel mælt.\nÁ ekkert sammerkt með MMA íþrottamanni', 'Djöfulsinns viðbjóður', 'Þessi drengur er svo mikið búin að drulla bæði mannorði og ferli ruslið.\n\nVona að hann sjái ljósið einn daginn og komi sínu lífi í lag,,, en þetta sem hann hefur verið að gera undanfarið er pjúra aumingjaskapur.', 'Bandaríska þjóðfélagið stefnir í nútímaútgáfuna af borgarastyrjöld. Er nánast að liðast í sundur og hrynja eins og Sovétríkin sálugu. Meðal ann ...

# %% [markdown]
# **Data Setup**

# %%
class Dataset():
    def __init__(self):
        self.words = self.load_words()
        self.uniq_words = self.get_uniq_words()

        self.index_to_word = {index: word for index, word in enumerate(self.uniq_words)}
        self.word_to_index = {word: index for index, word in enumerate(self.uniq_words)}

        self.words_indexes = [self.word_to_index[w] for w in self.words]

    def load_words(self):
        words = []
        for comment in comments:
          for word in comment.split(' '):
            words.append(word)
        return words

    def get_uniq_words(self):
        word_counts = Counter(self.words)
        return sorted(word_counts, key=word_counts.get, reverse=True)

    def __len__(self):
        return len(self.words_indexes) - 50

    def __getitem__(self, index):
        return (
            torch.tensor(self.words_indexes[index:index+50),
            torch.tensor(self.words_indexes[index+1:index+51]),
        )
# Out:
#   File "<ipython-input-83-458510cc4350>", line 27
#     torch.tensor(self.words_indexes[index:index+s50),
#                                                    ^
# SyntaxError: invalid syntax

# %%
dataset = Dataset()
print(dataset.get_uniq_words())
# Out:
# ['að', 'er', 'og', 'í', 'á', 'ekki', 'sem', 'það', 'til', 'um', 'með', 'en', 'við', 'fyrir', 'eru', 'hann', 'af', 'þetta', 'Það', 'þá', 'bara', 'því', 'ég', 'svo', 'eða', 'vera', 'hefur', 'hafa', 'var', 'verið', 'hjá', 'þú', 'eins', 'þeir', 'sér', 'Þetta', 'ekkert', 'eftir', 'sé', 'ef', 'hún', 'frá', 'Ég', 'fólk', 'upp', 'svona', 'hvað', 'þessi', 'nú', 'þegar', 'þess', 'sig', 'væri', 'hafi', 'allt', 'Er', 'þau', 'koma', 'þeim', 'þessu', '?', 'þessum', 'þér', 'fá', 'fara', 'þar', 'úr', 'verður', 'segja', 'Hvað', 'gera', 'út', 'þarf', 'vegna', 'En', 'alveg', 'yfir', 'þessa', 'maður', 'mér', 'ad', 'i', 'aldrei', 'rétt', 'sama', 'meira', 'eitthvað', 'vel', 'hefði', 'voru', 'of', 'Hann', 'ætti', 'hægt', 'heldur', 'fram', 'eiga', 'taka', 'hér', 'geta', 'fer', 'allir', 'Ekki', 'mikið', 'Og', '-', 'má', 'menn', 'hvort', 'Ef', 'hverju', 'sjá', 'gert', 'kemur', 'líka', ':)', 'alltaf', 'inn', 'annað', 'einhver', 'þó', 'Trump', 'ert', 'enn', 'margir', '<3', 'getur', 'a', 'honum', 'mun', 'hef', '!', 'séu', 'finnst', 'hans', 'fólki', 'okkar', 'mjög', 'okkur', ',', 'enginn', 'hvernig', 'öllum', 'Þú', 'engin', 'einn', 'þeirra', 'undir', 'gott', 'Hvernig', 'alla', 'orðið', 'fær', 'þennan', 'veit', 'sagt', 'nota', 'halda', 'þarna', 'Þessi', 'ađ', 'betur', 'vita', 'þig', 'verða', 'hver', 'segir', 'nema', 'ár', 'henni', 'held', '.', 'vilja', 'kannski', 'án', 'Af', 'hvaða', 'öðrum', 'eitt', 'áður', 'mig', 'Við', 'öll', 'sínum', 'myndi', 'sá', 'máli', 'Nú', 'gerir', 'farið', 'tala', 'mál', '2', 'vill', 'Íslandi', 'þið', 'vinna', 'niður', 'dag', 'frekar', 'þannig', 'Þeir', 'öllu', 'More', 'Nei', 'komið', 'hvar', 'aftur', 'fleiri', 'Svo', 'hlýtur', 'Já', '...', 'setja', 'sitt', 'láta', 'þurfa', 'hvers', 'búið', 'manni', 'Í', 'þessari', 'sinni', 'hana', 'gegn', 'tíma', 'verði', 'áfram', 'samt', 'þessar', 'sína', 'einhvern', 'bæði', 'auðvitað', 'konur', 'greinilega', 'milli', 'saman', 'lítið', 'einu', 'núna', 'enda', 'loka', 'Takk', 'hennar', 'borga', 'reyna', 'fyrst', 'raun', 'Hver', 'Arnar', 'Páll', 'ára', 'the', 'gæti', 'Brynjar', 'meðan', 'nokkuð', 'heitir', 'kalla', 'geti', 'fór', 'viðkomandi', 'Mér', 'skil', 'sagði', ':-)', 'takk', 'Eru', 'kom', 'sömu', 'mörg', 'fengið', 'sýnir', 'málið', 'sinn', 'ekki.', 'meiri', 'aðra', 'eiginlega', 'væru', 'lögreglan', 'eigin', 'allar', 'tekið', 'sérstaklega', 'erum', 'þær', 'Að', 'Bara', 'stað', 'sínu', 'Biden', 'hugsa', 'löngu', 'yrði', 'Hvaða', 'haldið', 'þessir', '❤️', 'ábyrgð', 'alls', 'síðan', 'betra', 'þann', 'hversu', 'ykkur', 'mín', 'eldri', 'km.', 'ætli', 'orð', 'gegnum', 'DV', 'Bjarni', 'haft', 'gengur', '30', 'sér.', 'kenna', 'hluti', 'hafði', '10', 'lög', 'tekur', 'nóg', 'börnin', 'Sammála', 'jafnvel', 'Hvar', 'Svona', '❤', 'það.', 'minna', 'Hún', ':D', 'sammála', 'Bjarna', 'Gunnar', 'öðru', 'annars', 'forseti', 'skuli', 'Ágústsson', 'drepa', 'Var', 'grein', 'Þegar', 'Á', 'myndir', '4', 'sú', 'Mikið', 'kominn', 'oft', 'leggja', 'varð', 'maðurinn', 'sín', 'ná', 'orðin', 'eina', 'munu', 'eigi', 'landi', '3', 'Því', 'varla', 'búin', 'allra', 'illa', ':(', 'fyrr', 'kona', 'lesa', 'ertu', 'það,', 'gaman', 'miður', 'senda', 'sennilega', 'getum', '18', 'finna', 'neitt', 'já', 'virðist', 'Einar', 'heim', 'Davíð', 'komast', 'hætta', 'vinnu', 'átt', 'mætti', 'séð', 'laun', 'einhverjum', 'hraði', 'fái', 'ættu', 'standa', 'fólks', 'nýtt', 'þvi', 'væntanlega', 'nánast', 'ganga', 'önnur', 'vantar', 'heyrt', 'leyfa', 'talað', 'lögum', 'einstaklingur', 'ljóst', 'fari', 'er.', 'reglur', 'börn', 'Andersen', 'vona', 'það?', 'get', 'Hér', 'Þór', 'komin', 'utan', 'innan', 'lagi', 'ofan', 'samkvæmt', 'Íslendingar', 'brot', 'landsins', 'reyndar', 'landinu', 'Kári', 'búnir', 'fólkið', '50', 'bull', 'fréttir', 'nei', 'daginn', 'komi', 'Vonandi', ':', 'boði', 'Eftir', 'engan', 'hins', 'einungis', 'Held', 'hátt', 'miklu', 'sig.', 'einfaldlega', 'skipta', '6', 'móti', ',,', 'stendur', 'flytja', 'Covid', 'Kannski', 'þeirri', 'fyrri', 'thad', 'for', 'best', 'átti', 'þeim.', 'minn', 'jú', 'líka.', 'skal', 'ræða', 'Hefur', 'skip ...

# %% [markdown]
# **The Model**

# %%
class Model(nn.Module):
    def __init__(self, dataset):
        super(Model, self).__init__()
        self.lstm_size = 128
        self.embedding_dim = 128
        self.num_layers = 3

        n_vocab = len(dataset.uniq_words)
        self.embedding = nn.Embedding(
            num_embeddings=n_vocab,
            embedding_dim=self.embedding_dim,
        )
        self.lstm = nn.LSTM(
            input_size=self.lstm_size,
            hidden_size=self.lstm_size,
            num_layers=self.num_layers,
            dropout=0.2,
        )
        self.fc = nn.Linear(self.lstm_size, n_vocab)

    def forward(self, x, prev_state):
        embed = self.embedding(x)
        output, state = self.lstm(embed, prev_state)
        logits = self.fc(output)
        return logits, state

    def init_state(self, sequence_length):
        return (torch.zeros(self.num_layers, sequence_length, self.lstm_size),
                torch.zeros(self.num_layers, sequence_length, self.lstm_size))

# %% [markdown]
# **Training**

# %%
import argparse
import torch
import numpy as np
from torch import nn, optim
from torch.utils.data import DataLoader

model = Model(dataset)
model.train()

dataloader = DataLoader(dataset, batch_size=128)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

for epoch in range(10):
    state_h, state_c = model.init_state(50)

    for batch, (x, y) in enumerate(dataloader):
        optimizer.zero_grad()

        y_pred, (state_h, state_c) = model(x, (state_h, state_c))
        loss = criterion(y_pred.transpose(1, 2), y)

        state_h = state_h.detach()
        state_c = state_c.detach()

        loss.backward()
        optimizer.step()

        print({ 'epoch': epoch, 'batch': batch, 'loss': loss.item() })
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-82-9bbbb661ce33> in <module>()
#      15     state_h, state_c = model.init_state(50)
#      16
# ---> 17     for x, y in enumerate(dataloader):
#      18         optimizer.zero_grad()
#      19
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     433         if self._sampler_iter is None:
#     434             self._reset()
# --> 435         data = self._next_data()
#     436         self._num_yielded += 1
#     437         if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     472
#     473     def _next_data(self):
# --> 474         index = self._next_index()  # may raise StopIteration
#     475         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     476         if self._pin_memory:
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py in _next_index(self)
#     425
#     426     def _next_index(self):
# --> 427         return next(self._sampler_iter)  # may raise StopIteration
#     428
#     429     def _next_data(self):
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/sampler.py in __iter__(self)
#     225     def __iter__(self):
#     226         batch = []
# --> 227         for idx in self.sampler:
#     228             batch.append(idx)
#     229             if len(batch) == self.batch_size:
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/sampler.py in __iter__(self)
#      65
#      66     def __iter__(self):
# ---> 67         return iter(range(len(self.data_source)))
#      68
#      69     def __len__(self) -> int:
#
# <ipython-input-61-1dfd9d8d92a3> in __len__(self)
#      21
#      22     def __len__(self):
# ---> 23         return len(self.words_indexes) - self.args.sequence_length
#      24
#      25     def __getitem__(self, index):
#
# AttributeError: 'Dataset' object has no attribute 'args'
